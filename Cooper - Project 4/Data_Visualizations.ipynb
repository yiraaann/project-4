# %%
import pandas as pd
from pathlib import Path

# %%
music_df_load = Path("Resources/musicdf_file1.csv")

# %%
music_df = pd.read_csv(music_df_load, encoding='ISO-8859-1')

# %%
music_df.head(10)
# Out:
#    year                                     track_name  track_popularity  \
# 0  2019                                   Cruel Summer                96
# 1  2023                                   Cruel Summer                96
# 2  2023                                         greedy                96
# 3  2023                          My Love Mine All Mine                94
# 4  2023                                    Lovin On Me                93
# 5  2023                               I Wanna Be Yours                93
# 6  2006                                      Unwritten                92
# 7  2023                                          Water                92
# 8  2023  I Remember Everything (feat. Kacey Musgraves)                92
# 9  2023                                        Houdini                92
#
#                                     album          artist_name  \
# 0                                   Lover         Taylor Swift
# ...

# %%
music_df.shape
# Out:
# (2400, 19)

# %%
#dropping all rows except for the top 10 rows

# %%
music_df_top10 = music_df.iloc[:10]

# %%
music_df_top10
# Out:
#    year                                     track_name  track_popularity  \
# 0  2019                                   Cruel Summer                96
# 1  2023                                   Cruel Summer                96
# 2  2023                                         greedy                96
# 3  2023                          My Love Mine All Mine                94
# 4  2023                                    Lovin On Me                93
# 5  2023                               I Wanna Be Yours                93
# 6  2006                                      Unwritten                92
# 7  2023                                          Water                92
# 8  2023  I Remember Everything (feat. Kacey Musgraves)                92
# 9  2023                                        Houdini                92
#
#                                     album          artist_name  \
# 0                                   Lover         Taylor Swift
# ...

# %%
music_df_top10.to_csv('musicdf_top10.csv', index=False)

# %%
df_copy = music_df.copy()

# %%
df_2023 = df_copy[df_copy['year'] == 2023].copy()

# %%
df_2023
# Out:
#    year                                     track_name  track_popularity  \
# 1  2023                                   Cruel Summer                96
# 2  2023                                         greedy                96
# 3  2023                          My Love Mine All Mine                94
# 4  2023                                    Lovin On Me                93
# 5  2023                               I Wanna Be Yours                93
# 7  2023                                          Water                92
# 8  2023  I Remember Everything (feat. Kacey Musgraves)                92
# 9  2023                                        Houdini                92
#
#                                     album     artist_name  \
# 1                                   Lover    Taylor Swift
# 2                                  greedy      Tate McRae
# 3  The Land Is Inhospitable and So Are We          Mitski
# 4                             Lovin On Me     Jack Harlow
# ...

# %%
df_2023 = df_2023.iloc[:11]

# %%
df_2023
# Out:
#    year                                     track_name  track_popularity  \
# 1  2023                                   Cruel Summer                96
# 2  2023                                         greedy                96
# 3  2023                          My Love Mine All Mine                94
# 4  2023                                    Lovin On Me                93
# 5  2023                               I Wanna Be Yours                93
# 7  2023                                          Water                92
# 8  2023  I Remember Everything (feat. Kacey Musgraves)                92
# 9  2023                                        Houdini                92
#
#                                     album     artist_name  \
# 1                                   Lover    Taylor Swift
# 2                                  greedy      Tate McRae
# 3  The Land Is Inhospitable and So Are We          Mitski
# 4                             Lovin On Me     Jack Harlow
# ...

# %%
music_df.drop(columns=['playlist_url', 'track_id', 'artist_id', 'mode','time_signature'], inplace=True)

# %%
music_df.head()
# Out:
#    year             track_name  track_popularity  \
# 0  2019           Cruel Summer                96
# 1  2023           Cruel Summer                96
# 2  2023                 greedy                96
# 3  2023  My Love Mine All Mine                94
# 4  2023            Lovin On Me                93
#
#                                     album   artist_name  \
# 0                                   Lover  Taylor Swift
# 1                                   Lover  Taylor Swift
# 2                                  greedy    Tate McRae
# 3  The Land Is Inhospitable and So Are We        Mitski
# 4                             Lovin On Me   Jack Harlow
#
#                                        artist_genres  artist_popularity  \
# 0                                            ['pop']                100
# 1                                            ['pop']                100
# 2                                            ['pop']                 85
# ...

# %%
music_df['duration_ms'] = music_df['duration_ms'] / 60000

# %%
music_df.head()
# Out:
#    year             track_name  track_popularity  \
# 0  2019           Cruel Summer                96
# 1  2023           Cruel Summer                96
# 2  2023                 greedy                96
# 3  2023  My Love Mine All Mine                94
# 4  2023            Lovin On Me                93
#
#                                     album   artist_name  \
# 0                                   Lover  Taylor Swift
# 1                                   Lover  Taylor Swift
# 2                                  greedy    Tate McRae
# 3  The Land Is Inhospitable and So Are We        Mitski
# 4                             Lovin On Me   Jack Harlow
#
#                                        artist_genres  artist_popularity  \
# 0                                            ['pop']                100
# 1                                            ['pop']                100
# 2                                            ['pop']                 85
# ...

# %%
music_df['duration_ms'] = music_df['duration_ms'].round(2)

# %%
music_df.head()
# Out:
#    year             track_name  track_popularity  \
# 0  2019           Cruel Summer                96
# 1  2023           Cruel Summer                96
# 2  2023                 greedy                96
# 3  2023  My Love Mine All Mine                94
# 4  2023            Lovin On Me                93
#
#                                     album   artist_name  \
# 0                                   Lover  Taylor Swift
# 1                                   Lover  Taylor Swift
# 2                                  greedy    Tate McRae
# 3  The Land Is Inhospitable and So Are We        Mitski
# 4                             Lovin On Me   Jack Harlow
#
#                                        artist_genres  artist_popularity  \
# 0                                            ['pop']                100
# 1                                            ['pop']                100
# 2                                            ['pop']                 85
# ...

# %%
music_df = music_df.rename(columns={'duration_ms': 'duration_min'})

# %%
music_df.head()
# Out:
#    year             track_name  track_popularity  \
# 0  2019           Cruel Summer                96
# 1  2023           Cruel Summer                96
# 2  2023                 greedy                96
# 3  2023  My Love Mine All Mine                94
# 4  2023            Lovin On Me                93
#
#                                     album   artist_name  \
# 0                                   Lover  Taylor Swift
# 1                                   Lover  Taylor Swift
# 2                                  greedy    Tate McRae
# 3  The Land Is Inhospitable and So Are We        Mitski
# 4                             Lovin On Me   Jack Harlow
#
#                                        artist_genres  artist_popularity  \
# 0                                            ['pop']                100
# 1                                            ['pop']                100
# 2                                            ['pop']                 85
# ...

# %%
unique_tracks = music_df['track_name'].nunique()

# %%
unique_tracks
# Out:
# 2220

# %%
unique_tracks = music_df.groupby("year")["track_name"].nunique()

# %%
unique_tracks
# Out:
# year
# 2000    100
# 2001    100
# 2002    100
# 2003     99
# 2004    100
# 2005    100
# 2006    100
# 2007    100
# 2008    100
# 2009    100
# 2010    100
# 2011    100
# 2012    100
# 2013    100
# 2014    100
# 2015    100
# 2016     99
# 2017    100
# 2018    100
# 2019    100
# 2020    100
# 2021    100
# 2022    100
# 2023    100
# Name: track_name, dtype: int64

# %%
unique_genres = music_df['artist_genres'].nunique()
unique_genres
# Out:
# 718

# %%
unique_popularity = music_df['track_popularity'].nunique()
unique_popularity
# Out:
# 72

# %%
df_sorted_year = music_df.sort_values(by='year').groupby('year')

# %%
df_sorted_year.head(50)
# Out:
#       year                               track_name  track_popularity  \
# 2098  2000  Thank God I Found You (feat. Joe & 98°)                59
# 1618  2000                                  Sexbomb                67
# 1619  2000                               The Riddle                67
# 1316  2000                Can't Fight The Moonlight                70
# 1315  2000                                  My Love                70
# ...    ...                                      ...               ...
# 113   2023                          La Bebe - Remix                86
# 114   2023                        Say Yes To Heaven                86
# 115   2023                                 Fast Car                86
# 116   2023                              Agora Hills                86
# 915   2023                               On My Mama                75
#
#                                   album      artist_name  \
# 2098                            Rainbow     Mariah Carey
# ...

# %%
unique_score = music_df.groupby('year')['track_popularity'].nunique()

# %%
unique_score
# Out:
# year
# 2000    31
# 2001    31
# 2002    32
# 2003    32
# 2004    32
# 2005    30
# 2006    35
# 2007    29
# 2008    28
# 2009    29
# 2010    33
# 2011    29
# 2012    24
# 2013    33
# 2014    27
# 2015    20
# 2016    24
# 2017    20
# 2018    22
# 2019    24
# 2020    37
# 2021    41
# 2022    36
# 2023    37
# Name: track_popularity, dtype: int64

# %%
music_df.to_csv('musicdf_file.csv', index=False)
